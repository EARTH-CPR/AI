# %%
#pip install openai
# Out:
# ...
#      ---------------------------------------- 0.0/125.2 kB ? eta -:--:--
#      -------------------------------------- 125.2/125.2 kB 7.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/362.9 kB ? eta -:--:--
#    --------------------------------------- 362.9/362.9 kB 11.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#    ---------------------------------------- 86.8/86.8 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/75.6 kB ? eta -:--:--
#    ---------------------------------------- 75.6/75.6 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/77.9 kB ? eta -:--:--
#    ---------------------------------------- 77.9/77.9 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/189.7 kB ? eta -:--:--
# ...

# %%
# FE에서 image 받는 코드

from flask import Flask, request, jsonify

app = Flask(__name__)

@app.route('/upload', methods=['POST'])
def upload_file():
    if 'file' not in request.files:
        return jsonify({'error': 'No file part'}), 400
    
    file = request.files['file']
    if file.filename == '':
        return jsonify({'error': 'No selected file'}), 400
    
    if file:
        file_path = f"./uploads/{file.filename}"
        file.save(file_path)
        return jsonify({'message': 'File uploaded successfully', 'file_path': file_path}), 200

if __name__ == '__main__':
    app.run(debug=True)

# %% [markdown]
# GPI API에서는 OCR 기능을 지원하지 않음. 그렇기 때문에 외부 OCR 툴을 사용해야 함.

# %%
#pip install pytesseract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#pip install google-cloud-vision
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/467.5 kB ? eta -:--:--
#    -------------------- ------------------- 235.5/467.5 kB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 467.5/467.5 kB 7.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/139.4 kB ? eta -:--:--
#    ---------------------------------------- 139.4/139.4 kB 8.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/200.9 kB ? eta -:--:--
#    --------------------------------------- 200.9/200.9 kB 12.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/50.1 kB ? eta -:--:--
#    ---------------------------------------- 50.1/50.1 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/220.0 kB ? eta -:--:--
#    --------------------------------------- 220.0/220.0 kB 13.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/426.9 kB ? eta -:--:--
# ...

# %%
import pytesseract
from PIL import Image

# Tesseract-OCR의 경로 설정 (필요한 경우)
# pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# 이미지 열기
image = Image.open(r'D:\2024신한해커톤\영수증 처리 프로젝트\test\example.jpg')

# 한글 인식을 위한 언어 설정 (lang='kor')
text = pytesseract.image_to_string(image, lang='kor')

print(text)
# Out:
# [ 대 기 ! 번 호 :1103]
#
# [※※*]
# 투 썸 엔 타 워 점 ( 가 맹 )
#
# 312-81-42519 161 102)3455-9230 정 성 필
# 서 울 용 산 구 남 산 공 원 길 105 ( 용 신 동 2 가 , 블
#
# 산 타 워
# 00086 포 인 트 카드 가 입 으 로 다 양 한 혜 택 을
# 만나보세요가 비비 ,2] 이 16,6 오
#
# 2020/01/05 15:29
#
# 골 : 즈 르 9
# 르 300 월
# 계

# %% [markdown]
# Google vision API Key : AIzaSyBCaXSGP1oZ-iQkxAWohr06QdRAttI1Wfo

# %%
import os
from google.cloud import vision
from google.cloud.vision_v1 import types

# 서비스 계정 키 파일 경로 설정
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r'path_to_your_service_account_key.json'

# 클라이언트 생성
client = vision.ImageAnnotatorClient()

# 이미지 파일 경로
image_path = r'D:\2024신한해커톤\영수증 처리 프로젝트\test\example.jpg'

# 이미지 파일 읽기
with open(image_path, 'rb') as image_file:
    content = image_file.read()

# 이미지 객체 생성
image = types.Image(content=content)

# 텍스트 감지 요청
response = client.text_detection(image=image)
texts = response.text_annotations

# 추출된 텍스트 출력
for text in texts:
    print(text.description)

# 오류 처리
if response.error.message:
    raise Exception(f'{response.error.message}')

# %%
import requests
import base64

# Google Cloud Vision API 엔드포인트
url = "https://vision.googleapis.com/v1/images:annotate"

# API 키 (문자열 형식)
api_key = "AIzaSyBCaXSGP1oZ-iQkxAWohr06QdRAttI1Wfo"

# 이미지 파일 경로
image_path = r'D:\2024신한해커톤\영수증 처리 프로젝트\test\example.jpg'

# 이미지 파일을 읽어서 Base64로 인코딩
with open(image_path, "rb") as image_file:
    encoded_image = base64.b64encode(image_file.read()).decode()

# 요청 페이로드 생성
payload = {
    "requests": [
        {
            "image": {
                "content": encoded_image
            },
            "features": [
                {
                    "type": "TEXT_DETECTION"
                }
            ]
        }
    ]
}

# API 요청 보내기
response = requests.post(url, json=payload, params={"key": api_key})

# 결과 출력
if response.status_code == 200:
    result = response.json()
    for annotation in result['responses'][0]['textAnnotations']:
        print(annotation['description'])
else:
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# Error: 403
# {
#   "error": {
#     "code": 403,
#     "message": "This API method requires billing to be enabled. Please enable billing on project #202235821807 by visiting https://console.developers.google.com/billing/enable?project=202235821807 then retry. If you enabled billing for this project recently, wait a few minutes for the action to propagate to our systems and retry.",
#     "status": "PERMISSION_DENIED",
#     "details": [
#       {
#         "@type": "type.googleapis.com/google.rpc.Help",
#         "links": [
#           {
#             "description": "Google developers console billing",
#             "url": "https://console.developers.google.com/billing/enable?project=202235821807"
#           }
#         ]
#       },
#       {
#         "@type": "type.googleapis.com/google.rpc.ErrorInfo",
#         "reason": "BILLING_DISABLED",
#         "domain": "googleapis.com",
#         "metadata": {
#           "consumer": "projects/202235821807",
# ...

# %%
import openai
import requests

# GPT API 키 설정
openai.api_key = 'org-0kDfgNAkwdzXtMRA4WKdmDBb'

# 이미지 파일 경로
image_path = './uploads/example.png'

# 이미지 파일을 읽고, 바이너리 데이터를 API에 보냅니다
with open(image_path, 'rb') as image_file:
    image_data = image_file.read()

# GPT API에 요청 보냄 (이미지 데이터 기반 명령어 생성)
response = openai.Image.create(
    prompt=
    """""",
    n=1,
    size="1024x1024",
    file=image_data
)

# GPT API의 응답 처리
command = response['choices'][0]['text']
print(f"Generated Command: {command}")

# %%
@app.route('/process_image', methods=['POST'])
def process_image():
    file_path = request.json.get('file_path')
    if not file_path:
        return jsonify({'error': 'File path is required'}), 400
    
    # GPT API로 이미지 데이터를 전송하여 응답을 받음
    command = generate_command_based_on_image(file_path)
    
    return jsonify({'command': command}), 200

def generate_command_based_on_image(file_path):
    # GPT API에 요청 보내기 (앞서 작성한 코드 사용)
    with open(file_path, 'rb') as image_file:
        image_data = image_file.read()
    
    response = openai.Image.create(
        prompt="Describe the content of the image and generate a command based on it.",
        n=1,
        size="1024x1024",
        file=image_data
    )
    return response['choices'][0]['text']
